# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: torch in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from timm) (2.4.1)
# Requirement already satisfied: torchvision in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from timm) (0.19.1)
# Requirement already satisfied: pyyaml in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from timm) (0.24.6)
# Requirement already satisfied: safetensors in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from huggingface_hub->timm) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from huggingface_hub->timm) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/conite/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (24.0)
# Requirement already satisfied: requests in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from huggingface_hub->timm) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/conite/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (4.12.0)
# Requirement already satisfied: sympy in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from torch->timm) (1.13.2)
# Requirement already satisfied: networkx in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from torch->timm) (2.8.8)
# Requirement already satisfied: jinja2 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: numpy in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from torchvision->timm) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from requests->huggingface_hub->timm) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/conite/anaconda3/envs/GPU_ENV/lib/python3.9/site-packages (from sympy->torch->timm) (1.3.0)
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 13.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: timm
# Successfully installed timm-1.0.15

# %%
# train_loader=train_loader,
# val_loader=val_loader,
# cal_loader=cal_loader,
# test_loader=test_loader,

import os
import torch
from torchvision import transforms
import timm
from huggingface_hub import login, hf_hub_download

# login()

# %%
# local_dir = "../assets/ckpts/uni2-h/"
# os.makedirs(local_dir, exist_ok=True)  # create directory if it does not exist
# hf_hub_download("MahmoodLab/UNI2-h", filename="pytorch_model.bin", local_dir=local_dir, force_download=True)
# timm_kwargs = {
#    'model_name': 'vit_giant_patch14_224',
#    'img_size': 224, 
#    'patch_size': 14, 
#    'depth': 24,
#    'num_heads': 24,
#    'init_values': 1e-5, 
#    'embed_dim': 1536,
#    'mlp_ratio': 2.66667*2,
#    'num_classes': 5, 
#    'no_embed_class': True,
#    'mlp_layer': timm.layers.SwiGLUPacked, 
#    'act_layer': torch.nn.SiLU, 
#    'reg_tokens': 8, 
#    'dynamic_img_size': True
#   }
# model = timm.create_model(**timm_kwargs)
# model.load_state_dict(torch.load(os.path.join(local_dir, "pytorch_model.bin"), map_location="cpu"), strict=True)
# transform = transforms.Compose(
#  [
#   transforms.Resize(224),
#   transforms.CenterCrop(224),
#   transforms.ToTensor(),
#   transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
#  ]
# )
# model.eval()
